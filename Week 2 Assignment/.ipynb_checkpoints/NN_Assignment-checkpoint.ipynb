# %% [markdown]
# # Neural Network Assignment

# %%
# !unzip -j homer_bart.zip -d ./homer_bart
# Out:
# Archive:  homer_bart.zip
#   inflating: ./homer_bart/bart58.bmp
#   inflating: ./homer_bart/bart70.bmp
#   inflating: ./homer_bart/bart64.bmp
#   inflating: ./homer_bart/bart162.bmp
#   inflating: ./homer_bart/bart65.bmp
#   inflating: ./homer_bart/bart71.bmp
#   inflating: ./homer_bart/bart59.bmp
#   inflating: ./homer_bart/bart67.bmp
#   inflating: ./homer_bart/bart73.bmp
#   inflating: ./homer_bart/bart98.bmp
#   inflating: ./homer_bart/bart161.bmp
#   inflating: ./homer_bart/bart149.bmp
#   inflating: ./homer_bart/bart148.bmp
#   inflating: ./homer_bart/bart160.bmp
#   inflating: ./homer_bart/bart99.bmp
#   inflating: ./homer_bart/bart72.bmp
#   inflating: ./homer_bart/bart66.bmp
#   inflating: ./homer_bart/bart62.bmp
#   inflating: ./homer_bart/bart76.bmp
#   inflating: ./homer_bart/bart89.bmp
#   inflating: ./homer_bart/bart158.bmp
#   inflating: ./homer_bart/bart164.bmp
#   inflating: ./homer_bart/bart165.bmp
#   inflating: ./homer_bart/bart159.bmp
# ...

# %%
import numpy as np
import glob
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
img_height, img_width = 64, 64
batch_size = 32


# Prepare lists to hold image data and labels
images = []
labels = []

homer_path = "./homer_bart.zip/Homer"
bart_path = "./homer_bart.zip/Bart"

# %%
for filename in glob.glob(os.path.join(homer_path, '*.bmp')):
    img = Image.open(filename).resize((img_width, img_height))
    images.append(np.array(img))
    labels.append(0)  # Label for Homer

for filename in glob.glob(os.path.join(bart_path, '*.bmp')):
    img = Image.open(filename).resize((img_width, img_height))
    images.append(np.array(img))
    labels.append(1)  # Label for Bart

# %%
images = np.array(images)
labels = np.array(labels)

# %%
images = images / 255.0

labels = to_categorical(labels, num_classes=2)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.1, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.1, random_state=42)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...
